# %% [markdown]
# # Example usage
#
# To use `pyvisvsm` in a project:

# %%
import pyvisvsm

print(pyvisvsm.__version__)
# Out:
# 0.1.0

# %% [markdown]
# ## Plotting static visualizations
# Now we import matplotlib to plot and our main class. Then, we obtain a static visualization of the policy and Infected class.

# %%
import matplotlib.pyplot as plt
import pyvisvsm.pyvisvsm as vsm
import os
fig = plt.figure()
vs_fig = vsm.VsmFigures(fig, data_dir="../data/")
vs_fig.load_data()
ax_states, fig_states = vs_fig.plot_states()
ax_policy, fig_policy = vs_fig.plot_policies()
fig, ax1, ax2, ax3, ax4 = vs_fig.dash_plot()
plt.show()
# Out:
# /home/saul/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:104: UserWarning: When passing multiple axes, layout keyword is ignored.
#   self.df_states.plot(
# /home/saul/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:104: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   self.df_states.plot(
# /home/saul/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:137: UserWarning: When passing multiple axes, layout keyword is ignored.
#   self.df_policy.plot(
# /home/saul/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:137: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
# ...

# %% [markdown]
# ## Building a dynamic visualization: Animating and recording
#
# To deploy the animation, we need to write and configure the parameters using the class method `VSMAnimator.rec`.

# %%
vs_an = vsm.VsmAnimator(fig)
print(vs_an.data_folder)
vs_an.set_up_axes(data_dir='../data/')
vs_an.load_data()
vs_an.record_animation()
# Out:
# ./data/
# /home/saul/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:402: UserWarning: You passed in an explicit save_count=32 which is being ignored in favor of len(frames)=2500.
#   anim = animation.FuncAnimation(
# VSMAnimation2024-07-01 10:12:03.635558.mp4
# rec: 7626it [01:16, 179.51it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/pyvisvsm/lib/python3.9/site-packages/matplotlib/animation.py:243, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     242 try:
# --> 243     yield self
#     244 finally:
#
# File ~/Insync/sauld@cimat.mx/Google Drive/UNISON/Ponencias/2024/SMUQ-Valencia2024-talk/pyvisvsm/src/pyvisvsm/pyvisvsm.py:432, in VsmAnimator.record_animation(self, video_file)
#     431 self.__call__(idx)
# --> 432 writer.grab_frame()
# ...
